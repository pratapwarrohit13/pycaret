# %%
from pycaret.classification import *
from pycaret.datasets import get_data

# %%
data = get_data('iris')
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
s = setup(data, target='species',session_id = 12345)
# Out:
# <style  type="text/css" >
# </style><table id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8row0_col1" class="data row0 col1" >12345</td>
#             </tr>
#             <tr>
#                         <th id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8row1_col1" class="data row1 col1" >species</td>
#             </tr>
#             <tr>
#                         <th id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8row2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8row2_col1" class="data row2 col1" >Multiclass</td>
#             </tr>
#             <tr>
#                         <th id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8row3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8row3_col1" class="data row3 col1" >Iris-setosa: 0, Iris-versicolor: 1, Iris-virginica: 2</td>
#             </tr>
#             <tr>
#                         <th id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8row4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8row4_col1" class="data row4 col1" >(150, 5)</td>
#             </tr>
#             <tr>
#                         <th id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8row5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8row5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8row6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8row6_col1" class="data row6 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8row7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8row7_col1" class="data row7 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8row8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8row9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8row9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8row10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8row10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8row11_col1" class="data row11 col1" >(104, 4)</td>
#             </tr>
#             <tr>
#                         <th id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8row12_col1" class="data row12 col1" >(46, 4)</td>
#             </tr>
#             <tr>
#                         <th id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8row13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8row14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8row15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8row15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8row16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8row16_col1" class="data row16 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8row17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8row17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8row18_col0" class="data row18 col0" >Use GPU</td>
#                         <td id="T_e4ea9128_a29a_11eb_98aa_00e93a2036e8row18_col1" class="data row18 col1" >False</td>
#             <

# %%
best = compare_models(n_select=25)
compare_model_results = pull()
# Out:
# <style  type="text/css" >
#     #T_9b9a4250_a29b_11eb_873a_00e93a2036e8 th {
#           text-align: left;
#     }#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row0_col0,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row1_col0,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row1_col1,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row1_col3,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row1_col4,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row1_col5,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row1_col6,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row1_col7,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row2_col0,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row2_col1,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row2_col2,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row2_col3,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row2_col4,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row2_col5,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row2_col6,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row2_col7,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row3_col0,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row3_col1,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row3_col3,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row3_col4,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row3_col5,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row3_col6,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row3_col7,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row4_col0,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row4_col1,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row4_col2,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row4_col3,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row4_col4,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row4_col5,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row4_col6,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row4_col7,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row5_col0,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row5_col1,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row5_col2,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row5_col3,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row5_col4,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row5_col5,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row5_col6,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row5_col7,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row6_col0,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row6_col1,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row6_col2,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row6_col3,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row6_col4,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row6_col5,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row6_col6,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row6_col7,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row7_col0,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row7_col1,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row7_col2,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row7_col3,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row7_col4,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row7_col5,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row7_col6,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row7_col7,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row8_col0,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row8_col1,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row8_col2,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row8_col3,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row8_col4,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row8_col5,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row8_col6,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row8_col7,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row9_col0,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row9_col1,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row9_col2,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row9_col3,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row9_col4,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row9_col5,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row9_col6,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row9_col7,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row10_col0,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row10_col1,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row10_col2,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row10_col3,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row10_col4,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row10_col5,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row10_col6,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row10_col7,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row11_col0,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row11_col1,#T_9b9a4250_a29b ...
#             text-align:  left;
#             text-align:  left;
#         }#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row0_col1,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row0_col2,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row0_col3,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row0_col4,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row0_col5,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row0_col6,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row0_col7,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row1_col2,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row3_col2{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row0_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row1_col8,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row2_col8,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row3_col8,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row4_col8,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row5_col8,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row6_col8,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row7_col8,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row8_col8,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row9_col8,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row10_col8,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row11_col8,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row12_col8,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row13_col8,#T_9b9a4250_a29b_11eb_873a_00e93a2036e8row14_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }</style><table id="T_9b9a4250_a29b_11eb_873a_00e93a2036e8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9b9a4250_a29b_11eb_873a_00e93a2036e8level0_row0" class="row_heading level0 row0" >qda</th>

# %%
print(best[:5])
# Out:
# [QuadraticDiscriminantAnalysis(priors=None, reg_param=0.0,
#                               store_covariance=False, tol=0.0001), LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                            solver='svd', store_covariance=False, tol=0.0001), GaussianNB(priors=None, var_smoothing=1e-09), LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=12345, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=-1, n_neighbors=5, p=2,
#                      weights='uniform')]

# %%
def predict(model, sepal_length, sepal_width, petal_length, petal_width):
  
    df = pd.DataFrame.from_dict({'sepal_length': [sepal_length], 'sepal_width': [sepal_width], 
                                 'petal_length': [petal_length], 'petal_width': [petal_width]})
    
    model_index = list(compare_model_results['Model']).index(model)
    model = best[model_index]
    pred = predict_model(model, df, raw_score=True)
    return {'Iris-setosa': pred['Score_Iris-setosa'][0].astype('float64'), 
            'Iris-versicolor': pred['Score_Iris-versicolor'][0].astype('float64'),
            'Iris-virginica' : pred['Score_Iris-virginica'][0].astype('float64')}

# %%
import gradio as gr

# %%
model = gr.inputs.Dropdown(list(compare_model_results['Model']), label="Model")
sepal_length = gr.inputs.Slider(minimum=1, maximum=10, default=data['sepal_length'].mean(), label = 'sepal_length')
sepal_width = gr.inputs.Slider(minimum=1, maximum=10, default=data['sepal_width'].mean(), label = 'sepal_width')
petal_length = gr.inputs.Slider(minimum=1, maximum=10, default=data['petal_length'].mean(), label = 'petal_length')
petal_width = gr.inputs.Slider(minimum=1, maximum=10, default=data['petal_width'].mean(), label = 'petal_width')

gr.Interface(predict, [model,sepal_length,sepal_width,petal_length,petal_width], "label", live=True).launch(debug=True)
# Out:
# Running locally at: http://127.0.0.1:7862/
# To create a public link, set `share=True` in `launch()`.
# Interface loading below...
#         <iframe
#             width="1000"
#             height="500"
#             src="http://127.0.0.1:7862/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-d8d385f5c9e2> in <module>
#       5 petal_width = gr.inputs.Slider(minimum=1, maximum=10, default=data['petal_width'].mean(), label = 'petal_width')
#       6
# ----> 7 gr.Interface(predict, [model,sepal_length,sepal_width,petal_length,petal_width], "label", live=True).launch(debug=True)
#
# ~\Anaconda3\envs\pycaret\lib\site-packages\gradio\interface.py in launch(self, inline, inbrowser, share, debug, auth)
#     456             while True:
#     457                 sys.stdout.flush()
# --> 458                 time.sleep(0.1)
#     459         is_in_interactive_mode = bool(getattr(sys, 'ps1', sys.flags.interactive))
#     460         if not is_in_interactive_mode:
#
# KeyboardInterrupt:
